# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import utils

# %%
spec = np.load('/Users/researchfellow/PhD/CodeAstro_workshop/CodeAstro_group_2/spectra_dataset_2500_unaugmented.npz')

# %%
spec.files
# Out:
# ['flux_low',
#  'flux_low_err',
#  'flux_high',
#  'flux_high_err',
#  'flux_high_smoothed',
#  'flux_high_smoothed_err',
#  'id',
#  'ra',
#  'dec',
#  'field',
#  'z',
#  'wavelength_low',
#  'wavelength_high']

# %%
spec['flux_high']
# Out:
# array([[ 5.88688544e-23, -4.37118945e-22,  1.46912032e-20, ...,
#          6.45361045e-22,  7.11287051e-21,  5.88688544e-23],
#        [ 5.27628299e-21,  2.53016621e-20, -6.81715106e-21, ...,
#          7.13269795e-21,  2.02039122e-21,  5.27628299e-21],
#        [ 3.00651522e-20,  5.48166919e-21,  1.94097667e-20, ...,
#          2.65063116e-20,  3.28057457e-20,  3.00651522e-20],
#        ...,
#        [ 1.63769865e-21, -3.17964347e-20,  2.48945334e-20, ...,
#         -1.53333586e-21, -7.96577949e-21,  1.63769865e-21],
#        [ 5.05450145e-21,  3.66668385e-20,  3.24515883e-20, ...,
#         -2.28161082e-21, -8.31851925e-21,  5.05450145e-21],
#        [ 2.15281959e-20,  6.83791125e-20,  5.84264455e-20, ...,
#          1.01407079e-20,  1.55037414e-20,  2.15281959e-20]],
#       shape=(1187, 2500))

# %%
plt.plot(spec['wavelength_high'], spec['flux_high'][300])

# %%
wavelength, flux = utils.open_spectrum('/Users/researchfellow/PhD/CodeAstro_workshop/CodeAstro_group_2/spectra_dataset_2500_unaugmented.npz', i=300)

# %%
utils.plot_spectrum(wavelength, flux)

# %%
# plots that look good - 300

# %%
spec['z'][300]
# Out:
# np.float64(1.944418937629505)

# %%
np.savez(
  'flux_low',
 'flux_low_err',
 'flux_high',
 'flux_high_err',
 'flux_high_smoothed',
 'flux_high_smoothed_err',
 'id',
 'ra',
 'dec',
 'field',
 'z',
 'wavelength_low',
 'wavelength_high'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 np.savez(spec[300])
#
# File /opt/anaconda3/envs/codeastro/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:261, in NpzFile.__getitem__(self, key)
#     259         return self.zip.read(key)
#     260 else:
# --> 261     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: '300 is not a file in the archive'

# %%
spec
# Out:
# NpzFile '/Users/researchfellow/PhD/CodeAstro_workshop/CodeAstro_group_2/spectra_dataset_2500_unaugmented.npz' with keys: flux_low, flux_low_err, flux_high, flux_high_err, flux_high_smoothed...
